# %%
from exchangelib import DELEGATE, Account, Credentials

credentials = Credentials(
    username='ddom.ad.corp\\sgasmi', 
    password='Pilote01#'
)
account = Account(
    primary_smtp_address='sabri.gasmi@framatome.com', 
    credentials=credentials, 
    autodiscover=True, 
    access_type=DELEGATE
)
# Print first 100 inbox messages in reverse order
for item in account.inbox.all().order_by('-datetime_received')[:100]:
    print(item.subject, item.body, item.attachments)
# Out:
# ---------------------------------------------------------------------------
# AutoDiscoverFailed                        Traceback (most recent call last)
# <ipython-input-1-10eb7825833c> in <module>
#       5     password='Pilote01#'
#       6 )
# ----> 7 account = Account(
#       8     primary_smtp_address='sabri.gasmi@framatome.com',
#       9     credentials=credentials,
#
# ~\Miniconda3\lib\site-packages\exchangelib\account.py in __init__(self, primary_smtp_address, fullname, access_type, autodiscover, credentials, config, locale, default_timezone)
#     118             else:
#     119                 retry_policy, auth_type = None, None
# --> 120             self.ad_response, self.protocol = discover(
#     121                 email=primary_smtp_address, credentials=credentials, auth_type=auth_type, retry_policy=retry_policy
#     122             )
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in discover(email, credentials, auth_type, retry_policy)
#      22
#      23 def discover(email, credentials=None, auth_type=None, retry_policy=None):
# ---> 24     return Autodiscovery(
#      25         email=email, credentials=credentials, auth_type=auth_type, retry_policy=retry_policy
#      26     ).discover()
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in discover(self)
#     122             else:
#     123                 # This will cache the result
# --> 124                 ad_response = self._step_1(hostname=domain)
#     125
#     126         log.debug('Released autodiscover_cache_lock')
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_1(self, hostname)
#     432             return self._step_5(ad=ad)
#     433         else:
# --> 434             return self._step_2(hostname=hostname)
#     435
#     436     def _step_2(self, hostname):
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_2(self, hostname)
#     450             return self._step_5(ad=ad)
#     451         else:
# --> 452             return self._step_3(hostname=hostname)
#     453
#     454     def _step_3(self, hostname):
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_3(self, hostname)
#     486                 return self._step_4(hostname=hostname)
#     487         else:
# --> 488             return self._step_4(hostname=hostname)
#     489
#     490     def _step_4(self, hostname):
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_4(self, hostname)
#     513             srv_host = None
#     514         if not srv_host:
# --> 515             return self._step_6()
#     516         else:
#     517             redirect_url = 'https://%s/Autodiscover/Autodiscover.xml' % srv_host
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_6(self)
#     571
#     572         """
# --> 573         raise AutoDiscoverFailed(
#     574             'All steps in the autodiscover protocol failed for email %r. If you think this is an error, consider doing '
#     575             'an official test at https://testconnectivity.microsoft.com' % self.email)
#
# AutoDiscoverFailed: All steps in the autodiscover protocol failed for email 'sabri.gasmi@framatome.com'. If you think this is an error, consider doing an official test at https://testconnectivity.microsoft.com

# %%
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# <ipython-input-7-66322bbf1e9b> in <module>
#       1 # create an IMAP4 class with SSL
# ----> 2 imap = imaplib.IMAP4_SSL("imap.gmail.com")
#       3 # authenticate
#       4 imap.login(username, password)
#
# ~\Miniconda3\lib\imaplib.py in __init__(self, host, port, keyfile, certfile, ssl_context)
#    1295                                                          keyfile=keyfile)
#    1296             self.ssl_context = ssl_context
# -> 1297             IMAP4.__init__(self, host, port)
#    1298
#    1299         def _create_socket(self):
#
# ~\Miniconda3\lib\imaplib.py in __init__(self, host, port)
#     196         # Open socket to server.
#     197
# --> 198         self.open(host, port)
#     199
#     200         try:
#
# ~\Miniconda3\lib\imaplib.py in open(self, host, port)
#    1308                 read, readline, send, shutdown.
#    1309             """
# -> 1310             IMAP4.open(self, host, port)
#    1311
#    1312     __all__.append("IMAP4_SSL")
#
# ~\Miniconda3\lib\imaplib.py in open(self, host, port)
#     301         self.host = host
#     302         self.port = port
# --> 303         self.sock = self._create_socket()
#     304         self.file = self.sock.makefile('rb')
#     305
#
# ~\Miniconda3\lib\imaplib.py in _create_socket(self)
#    1298
#    1299         def _create_socket(self):
# -> 1300             sock = IMAP4._create_socket(self)
#    1301             return self.ssl_context.wrap_socket(sock,
#    1302                                                 server_hostname=self.host)
#
# ~\Miniconda3\lib\imaplib.py in _create_socket(self)
#     291         host = None if not self.host else self.host
#     292         sys.audit("imaplib.open", self, self.host, self.port)
# --> 293         return socket.create_connection((host, self.port))
#     294
#     295     def open(self, host = '', port = IMAP4_PORT):
#
# ~\Miniconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     785     host, port = address
#     786     err = None
# --> 787     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     788         af, socktype, proto, canonname, sa = res
#     789         sock = None
#
# ~\Miniconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     916     # and socket type values to enum constants.
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#     920         addrlist.append((_intenum_converter(af, AddressFamily),
#
# gaierror: [Errno 11001] getaddrinfo failed

# %%
credentials = Credentials(
    username='MYWINDOMAIN\\sgasmi',  # Or myusername@example.com for O365
    password='Pilote01#'
)
account = Account(
    primary_smtp_address='sabri.gasmi@framatome.com', 
    credentials=credentials, 
    autodiscover=True, 
    access_type=DELEGATE
)
# Print first 100 inbox messages in reverse order
for item in account.inbox.all().order_by('-datetime_received')[:100]:
    print(item.subject, item.body, item.attachments)
# Out:
# ---------------------------------------------------------------------------
# AutoDiscoverFailed                        Traceback (most recent call last)
# <ipython-input-3-bf210608aa85> in <module>
#       3     password='Pilote01#'
#       4 )
# ----> 5 account = Account(
#       6     primary_smtp_address='sabri.gasmi@framatome.com',
#       7     credentials=credentials,
#
# ~\Miniconda3\lib\site-packages\exchangelib\account.py in __init__(self, primary_smtp_address, fullname, access_type, autodiscover, credentials, config, locale, default_timezone)
#     118             else:
#     119                 retry_policy, auth_type = None, None
# --> 120             self.ad_response, self.protocol = discover(
#     121                 email=primary_smtp_address, credentials=credentials, auth_type=auth_type, retry_policy=retry_policy
#     122             )
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in discover(email, credentials, auth_type, retry_policy)
#      22
#      23 def discover(email, credentials=None, auth_type=None, retry_policy=None):
# ---> 24     return Autodiscovery(
#      25         email=email, credentials=credentials, auth_type=auth_type, retry_policy=retry_policy
#      26     ).discover()
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in discover(self)
#     122             else:
#     123                 # This will cache the result
# --> 124                 ad_response = self._step_1(hostname=domain)
#     125
#     126         log.debug('Released autodiscover_cache_lock')
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_1(self, hostname)
#     432             return self._step_5(ad=ad)
#     433         else:
# --> 434             return self._step_2(hostname=hostname)
#     435
#     436     def _step_2(self, hostname):
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_2(self, hostname)
#     450             return self._step_5(ad=ad)
#     451         else:
# --> 452             return self._step_3(hostname=hostname)
#     453
#     454     def _step_3(self, hostname):
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_3(self, hostname)
#     486                 return self._step_4(hostname=hostname)
#     487         else:
# --> 488             return self._step_4(hostname=hostname)
#     489
#     490     def _step_4(self, hostname):
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_4(self, hostname)
#     513             srv_host = None
#     514         if not srv_host:
# --> 515             return self._step_6()
#     516         else:
#     517             redirect_url = 'https://%s/Autodiscover/Autodiscover.xml' % srv_host
#
# ~\Miniconda3\lib\site-packages\exchangelib\autodiscover\discovery.py in _step_6(self)
#     571
#     572         """
# --> 573         raise AutoDiscoverFailed(
#     574             'All steps in the autodiscover protocol failed for email %r. If you think this is an error, consider doing '
#     575             'an official test at https://testconnectivity.microsoft.com' % self.email)
#
# AutoDiscoverFailed: All steps in the autodiscover protocol failed for email 'sabri.gasmi@framatome.com'. If you think this is an error, consider doing an official test at https://testconnectivity.microsoft.com
